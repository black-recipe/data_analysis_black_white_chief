# %%
import pandas as pd

data = pd.read_csv('서울리뷰전체.csv',encoding='utf-8-sig')
data.head()
# Out:
#            가게명  주요판매요리  서울구         상세주소  좌표정보     리뷰수  리뷰평점 예약진행여부  \
# 0       SOIGNE   컨템포러리  강남구  강남구 신사동 652   NaN  1633.0   4.8   예약가능
# 1      드레스덴 그린    코스요리  강남구      강남구 청담동   NaN   382.0   4.6   예약가능
# 2  코자차 kojacha   컨템포러리  강남구      강남구 청담동   NaN   402.0   4.7   예약가능
# 3          면서울      한식  강남구   강남구 압구정로데오   NaN  1216.0   4.5   예약가능
# 4     뜨라또리아 샘킴  이탈리아음식  강남구   강남구 압구정로데오   NaN  1328.0   4.6   예약마감
#
#                             평균가격대 셰프닉네임  셰프명                      특징
# 0               24만원(점심)/38만원(저녁)    이준   이준  미슐랭 2스타/Taste of Seoul
# 1               17만원(점심)/27만원(저녁)  천생연분  박가람         섬세한 플레이팅/예약금 0원
# 2           13.5만원(점심)/22.5만원(저녁)   NaN  최유강           2022-2024 미슐랭
# 3                           1-3만원   김도윤  김도윤                미슐랭 빕구르망
# 4  8.5-10.5만원(점심)/14.9-18.9만원(저녁)    샘킴  NaN             자동결제/예약금 0원

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   가게명     59 non-null     object
#  1   주요판매요리  59 non-null     object
#  2   서울구     56 non-null     object
#  3   상세주소    56 non-null     object
#  4   좌표정보    0 non-null      float64
#  5   리뷰수     26 non-null     float64
#  6   리뷰평점    26 non-null     float64
#  7   예약진행여부  58 non-null     object
#  8   평균가격대   33 non-null     object
#  9   셰프닉네임   52 non-null     object
#  10  셰프명     46 non-null     object
#  11  특징      58 non-null     object
# dtypes: float64(3), object(9)
# memory usage: 5.7+ KB
