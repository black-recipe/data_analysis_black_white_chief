# %% [markdown]
# # 흑백요리사 식당 50m 격자 생성 및 시각화
#
# 이 노트북은 `캐치테이블_가게정보.csv` 파일의 위도/경도 정보를 활용하여 다음 작업을 수행합니다.
# 1. **좌표계 변환**: WGS84(위경도) -> EPSG:5179(미터 좌표계)
# 2. **격자 생성**: 각 식당 기준 반경 50m를 커버하는 정사각형 격자 생성
# 3. **시각화**: Folium을 이용한 지도 시각화

# %%
import geopandas as gpd
import pandas as pd
import folium
from shapely.geometry import Point
import os

# %%
# 데이터 파일 경로
file_path = r"c:\Users\USER\Documents\웅진씽크빅kdt\흑백요리사\캐치테이블_가게정보.csv"

# CSV 읽기
df = pd.read_csv(file_path)
print(f"✅ 데이터 로드 완료: {len(df)}개 식당")
df[['restaurant', 'lat', 'lon']].head()
# Out:
# ✅ 데이터 로드 완료: 118개 식당
#             restaurant        lat         lon
# 0          유용욱 바베큐 연구소  37.543957  126.972782
# 1    IMOK Smoke Dining  37.521126  127.019125
# 2                라망시크레  37.559666  126.979542
# 3  Original Numbers 청담  37.525096  127.040738
# 4        앰배서더 서울 풀만 호빈  37.560592  127.002094

# %%
def create_50m_grid_from_locations(df, lat_col, lon_col):
    """
    위경도 데이터를 받아 50m 격자(EPSG:5179)를 생성하는 함수
    """
    # 1. GeoDataFrame 생성 (EPSG:4326)
    geometry = [Point(xy) for xy in zip(df[lon_col], df[lat_col])]
    gdf = gpd.GeoDataFrame(df, geometry=geometry, crs="EPSG:4326")
    
    # 2. 좌표계 변환 (EPSG:5179)
    gdf_proj = gdf.to_crs(epsg=5179)
    
    # 3. 50m 버퍼 -> 사각형(Envelope) 변환
    gdf_proj['grid_geometry'] = gdf_proj.geometry.buffer(50).envelope
    
    # 4. grid_geometry를 메인으로 설정하고 정리
    gdf_grid = gdf_proj.set_geometry('grid_geometry')
    gdf_grid = gdf_grid.drop(columns=['geometry'], errors='ignore') # 기존 Point 컬럼 삭제
    gdf_grid = gdf_grid.rename_geometry('geometry')
    
    return gdf_grid

# %%
# 함수 실행
try:
    gdf_result = create_50m_grid_from_locations(df, 'lat', 'lon')
    
    # 면적 계산 (검증)
    gdf_result['area_m2'] = gdf_result.geometry.area
    
    print("✅ 격자 생성 완료!")
    display(gdf_result[['restaurant', 'area_m2', 'geometry']].head())
    
except Exception as e:
    print(f"❌ 오류 발생: {e}")
# Out:
# ✅ 격자 생성 완료!
#             restaurant  area_m2  \
# 0          유용욱 바베큐 연구소  10000.0
# 1    IMOK Smoke Dining  10000.0
# 2                라망시크레  10000.0
# 3  Original Numbers 청담  10000.0
# 4        앰배서더 서울 풀만 호빈  10000.0
#
#                                             geometry
# 0  POLYGON ((953376.305 1949483.645, 953476.305 1...
# 1  POLYGON ((957457.298 1946928.729, 957557.298 1...
# 2  POLYGON ((953983.127 1951223.172, 954083.127 1...
# 3  POLYGON ((959369.257 1947359.589, 959469.257 1...
# 4  POLYGON ((955975.477 1951315.083, 956075.477 1...

# %%
# 시각화를 위해 다시 위경도 좌표계(EPSG:4326)로 변환
gdf_viz = gdf_result.to_crs(epsg=4326)

# 중심점 계산
center_lat = gdf_viz.geometry.centroid.y.mean()
center_lon = gdf_viz.geometry.centroid.x.mean()

# 지도 생성
m = folium.Map(location=[center_lat, center_lon], zoom_start=12)

# 격자 추가
folium.GeoJson(
    gdf_viz,
    name='50m Grid',
    style_function=lambda x: {'fillColor': '#ff0000', 'color': 'red', 'weight': 1, 'fillOpacity': 0.3},
    tooltip=folium.GeoJsonTooltip(fields=['restaurant', 'area_m2'], aliases=['식당명', '면적(m2)'])
).add_to(m)

# 지도 출력
m
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_17696\971523552.py:5: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center_lat = gdf_viz.geometry.centroid.y.mean()
# C:\Users\USER\AppData\Local\Temp\ipykernel_17696\971523552.py:6: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   center_lon = gdf_viz.geometry.centroid.x.mean()
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7ed8033e20d22c68e9e1b74d4b9255b8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7ed8033e20d22c68e9e1b74d4b9255b8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7ed8033e20d22c68e9e1b74d4b9255b8 = L.map(
#                 &quot;map_7ed8033e20d22c68e9e1b74d4b9255b8&quot;,
#                 {
#                     center: [37.53878964088663, 127.00172669237703],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a6db3359ce141b9dd16d6836cbf554bd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a6db3359ce141b9dd16d6836cbf554bd.addTo(map_7ed8033e20d22c68e9e1b74d4b9255b8);
#
#
#         function geo_json_13cbedb138af1809cc5a58d40e064ad9_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;red&quot;, &quot;fillColor&quot;: &quot;#ff0000&quot;, &quot;fillOpacity&quot;: 0.3, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_13cbedb138af1809cc5a58d40e064ad9_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_13cbedb138af1809cc5a58d40e064ad9 = L.geoJson(null, {
#                 onEachFeature: geo_json_13cbedb138af1809cc5a58d40e064ad9_onEachFeature,
#
#                 style: geo_json_13cbedb138af1809cc5a58d40e064ad9_styler,
#             ...{
# }
#         });
#
#         function geo_json_13cbedb138af1809cc5a58d40e064ad9_add (data) {
#             geo_json_13cbedb138af1809cc5a58d40e064ad9
#                 .addData(data);
#         }
#             geo_json_13cbedb138af1809cc5a58d40e064ad9_add({&quot;bbox&quot;: [126.8185528067096, 37.46294239214708, 127.12464962970783, 37.61995832325612], &quot;features&quot;: [{&quot;bbox&quot;: [126.97221264059344, 37.543504010791, 126.97335095259325, 37.54441038654347], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[126.97221899477911, 37.543504010791], [126.97335095259325, 37.54350906477563], [126.97334461203417, 37.54441038654347], [126.97221264059344, 37.54440533239531], [126.97221899477911, 37.543504010791]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;URL&quot;: &quot;https://app.catchtable.co.kr/ct/shop/yyw?type=DINING&quot;, &quot;area_m2&quot;: 10000.0, &quot;badge_info&quot;: null, &quot;category&quot;: &quot;\ubc14\ubca0\ud050&quot;, &quot;chief_info&quot;: &quot;\ubc14\ubca0\ud050\uc5f0\uad6c\uc18c\uc7a5&quot;, &quot;dinner_price&quot;: &quot;\uc800\ub141 15\ub9cc\uc6d0&quot;, &quot;lat&quot;: 37.5439572, &quot;location&quot;: &quot;\ub0a8\uc601&quot;, &quot;lon&quot;: 126.9727818, &quot;price&quot;: &quot;\uc810\uc2ec \uc800\ub141 \ub3d9\uc77c\uac00 10 - 15\ub9cc\uc6d0 \u2022 \uc800\ub141 15\ub9cc\uc6d0&quot;, &quot;rating&quot;: 4.8, &quot;restaurant&quot;: &quot;\uc720\uc6a9\uc6b1 \ubc14\ubca0\ud050 \uc5f0\uad6c\uc18c&quot;, &quot;review_count&quot;: &quot;268&quot;, &quot;status_time&quot;: &quot;\uc601\uc5c5\uc911 \u2022 12:00-21:00&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [127.01855659041125, 37.520673229138474, 127.01969400278296, 37.521579168190975], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.01856238189096, 37.520673229138474], [127.01969400278296, 37.52067783650634], [127.01968822491486, 37.521579168190975], [127.01855659041125, 37.521574560674], [127.01856238189096, 37.520673229138474]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;URL&quot;: &quot;https://app.catchtable.co.kr/ct/shop/imok?type=DINING&quot;, &quot;area_m2&quot;: 10000.0, &quot;badge_info&quot;: null, &quot;category&quot;: &quot;\ubc14\ubca0\ud050&quot;, &quot;chief_info&quot;: &quot;\ubc14\ubca0\ud050\uc5f0\uad6c\uc18c\uc7a5&quot;, &quot;dinner_price&quot;: &quot;\uc800\ub141 15-22\ub9cc\uc6d0&quot;, &quot;lat&quot;: 37.5211262, &quot;location&quot;: &quot;\uc2e0\uc0ac&quot;, &quot;lon&quot;: 127.0191253, &quot;pric

# %%
# 결과 저장
output_geojson = r"c:\Users\USER\Documents\웅진씽크빅kdt\흑백요리사\result_grid_50m.geojson"
gdf_result.to_file(output_geojson, driver='GeoJSON')
print(f"💾 파일 저장 완료: {output_geojson}")
